# %%
import folium

# %%
m = folium.Map(location=[34.05,-118.3],zoom_start=12) #12 
# food places are red 
folium.Marker(location=[34.0638565,-118.3005673],popup="Dongdaemun - Yupdduk (Fried Chicken)",icon=folium.Icon(color='red',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0475514,-118.3194437],popup="Pasta Sisters",icon=folium.Icon(color='red',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0602223,-118.2934236],popup="77 Kentucky",icon=folium.Icon(color='red',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0612976,-118.2414198],popup="Howlin’ Ray (spiciest chicken)",icon=folium.Icon(color='red',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0628027,-118.1236689],popup="Mama Lu’s (dumplings)",icon=folium.Icon(color='red',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0597724,-118.2392237],popup="Philippe the Original",icon=folium.Icon(color='red',prefix='fa',icon='cutlery')).add_to(m)

folium.Marker(location=[34.046773,-118.2531897],popup="Guisados (Taco place in downtown LA)",icon=folium.Icon(color='blue',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0702535,-118.2524526],popup="Guisados (Taco place in downtown LA)",icon=folium.Icon(color='blue',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0481748,-118.2136631],popup="Guisados (Taco place in downtown LA)",icon=folium.Icon(color='blue',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0844275,-118.3874337],popup="Guisados (Taco place in downtown LA)",icon=folium.Icon(color='blue',prefix='fa',icon='cutlery')).add_to(m)

folium.Marker(location=[34.0464095,-118.3479041],popup="Leo’s Taco Truck",icon=folium.Icon(color='orange',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0469514,-118.291662],popup="Leo’s Taco Truck",icon=folium.Icon(color='orange',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0445322,-118.2941108],popup="Leo’s Taco Truck",icon=folium.Icon(color='orange',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0677744,-118.2633137],popup="Leo’s Taco Truck",icon=folium.Icon(color='orange',prefix='fa',icon='cutlery')).add_to(m)


folium.Marker(location=[34.1429893,-118.2575329],popup="Din Tai Fung",icon=folium.Icon(color='green',prefix='fa',icon='cutlery')).add_to(m)
#folium.Marker(location=[34.1331948,-118.0545991],popup="Din Tai Fung",icon=folium.Icon(color='green',prefix='fa',icon='cutlery')).add_to(m)
#folium.Marker(location=[34.1272965,-118.0564285],popup="Din Tai Fung",icon=folium.Icon(color='green',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[34.0590075,-118.4210547],popup="Din Tai Fung",icon=folium.Icon(color='green',prefix='fa',icon='cutlery')).add_to(m)
folium.Marker(location=[37.3255699,-121.9471889],popup="Din Tai Fung",icon=folium.Icon(color='green',prefix='fa',icon='cutlery')).add_to(m)

folium.Marker(location=[33.9915403,-118.4593633],popup="airbnb",icon=folium.Icon(color='black',prefix='fa',icon='circle')).add_to(m)

# purple museum - image
folium.Marker(location=[33.926709,-117.8866637],popup="Museum of Jurassic Technology",icon=folium.Icon(color='purple',prefix='fa',icon='image')).add_to(m)
folium.Marker(location=[34.0596505,-118.4459541],popup="Hammer Museum",icon=folium.Icon(color='purple',prefix='fa',icon='image')).add_to(m)
folium.Marker(location=[33.926709,-117.8866637],popup="The Broad (Art Museum)",icon=folium.Icon(color='purple',prefix='fa',icon='image')).add_to(m)
folium.Marker(location=[34.1290496,-118.1167129],popup="Huntington Library, Art Collections and Botanical Gardens",icon=folium.Icon(color='purple',prefix='fa',icon='image')).add_to(m)
folium.Marker(location=[34.0780402,-118.4762841],popup="The getty art museum",icon=folium.Icon(color='purple',prefix='fa',icon='image')).add_to(m)

# purple sights - wheelchair-alt
folium.Marker(location=[34.0639132,-118.3587605],popup="La Brea Tar Pits (fossils)",icon=folium.Icon(color='purple',prefix='fa',icon='wheelchair-alt')).add_to(m)
folium.Marker(location=[33.9838593,-118.4691687],popup="Venice Canals",icon=folium.Icon(color='purple',prefix='fa',icon='wheelchair-alt')).add_to(m)
folium.Marker(location=[30.0577726,-118.1135046],popup="Disney",icon=folium.Icon(color='purple',prefix='fa',icon='wheelchair-alt')).add_to(m)
folium.Marker(location=[34.0717633,-118.3630058],popup="farmers market",icon=folium.Icon(color='purple',prefix='fa',icon='wheelchair-alt')).add_to(m)
folium.Marker(location=[34.1340258,-118.3238652],popup="hollywood sign",icon=folium.Icon(color='purple',prefix='fa',icon='wheelchair-alt')).add_to(m)
folium.Marker(location=[34.054079,-118.2500289],popup="little tokyo",icon=folium.Icon(color='purple',prefix='fa',icon='wheelchair-alt')).add_to(m)
folium.Marker(location=[34.0430219,-118.2694428],popup="STAPLES center",icon=folium.Icon(color='purple',prefix='fa',icon='wheelchair-alt')).add_to(m)
folium.Marker(location=[34.0161067,-118.4987285],popup="Third Street Promenade (Farmers Market)",icon=folium.Icon(color='purple',prefix='fa',icon='wheelchair-alt')).add_to(m)


# purple high places - rupee
#folium.Marker(location=[33.9387848,-118.2438038],popup="Watts Tower",icon=folium.Icon(color='purple',prefix='fa',icon='rupee')).add_to(m)
folium.Marker(location=[34.1184385,-118.3025822],popup="Griffith Observatory",icon=folium.Icon(color='purple',prefix='fa',icon='rupee')).add_to(m)
folium.Marker(location=[34.053718,-118.244842],popup="Los Angeles City Hall",icon=folium.Icon(color='purple',prefix='fa',icon='rupee')).add_to(m)



folium.Marker(location=[34.1992632,-118.1774972],popup="JPL",icon=folium.Icon(color='purple',prefix='fa',icon='heartbeat')).add_to(m)
folium.Marker(location=[34.1003663,-118.2921697],popup="soap plant / wacko",icon=folium.Icon(color='purple',prefix='fa',icon='heartbeat')).add_to(m)

# purple beaches - heartbeat
#folium.Marker(location=[34.038047,-118.8768517],popup="El Matador beach",icon=folium.Icon(color='purple',prefix='fa',icon='heartbeat')).add_to(m)




m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
